# %%
import requests
import json

# %%
token = "9b0d6ca2db3de2046e5093db6908b2655159e5b5"

# %%
headers={"Authorization":f"Token {token}" }
path = '/home/beedata/Documents/uni/DataIngestionWebApp/pythonProject/WebApp/sample_data/Tech task data - Sheet1.csv'
files = {"upload_file": open(path,"r")}

r = requests.post('http://localhost:8000/data-ingestion/invoice-upload/', headers=headers,files=files)
r
# Out:
# <Response [200]>

# %%
r.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 r.content
#
# NameError: name 'r' is not defined

# %%
headers={"Authorization":f"Token {token}" }
payload = {'revenue_source':'Happy Playcrows'}
r = requests.get("http://localhost:8000/data-ingestion/invoices/get-advance/", headers=headers, params=payload)
r.json()
# Out:
# {'revenue_source': {'0': ' May Jewelers',
#   '1': ' May Jewelers ',
#   '2': 'AO UK',
#   '3': 'AlexUndeR',
#   '4': 'Apple',
#   '5': 'Bo.com UK & IE',
#   '6': 'CloudMedia',
#   '7': 'Costco',
#   '8': 'Costco ',
#   '9': 'Facebook',
#   '10': 'Fierra',
#   '11': 'Fierra ',
#   '12': 'Freewhere',
#   '13': 'Google Inc',
#   '14': 'Happy Playcrows',
#   '15': 'Improve Digital',
#   '16': 'Index Playcrows',
#   '17': 'Little cup',
#   '18': 'Mars Parts',
#   '19': "Mom's Club",
#   '20': "Mom's Club ",
#   '21': 'OA KU',
#   '22': 'OpenX',
#   '23': 'Overdrone',
#   '24': 'Playwear',
#   '25': "Sam's bulb",
#   '26': 'SkyLTD',
#   '27': 'SpotX Replay',
#   '28': 'SuperAmazing',
#   '29': 'The Trade Desk',
#   '30': 'TnT Internet ',
#   '31': 'TnT Mobility',
#   '32': 'TnT Mobility ',
#   '33': 'automatic'},
#  'value': {'0': 129206.31700000001,
#   '1': 126571.588,
#   '2': 1137418.7999999998,
#   '3': 470471.292,
#   '4': 4666.15,
#   '5': 350747.6,
#   '6': 2822907.606,
#   '7': 465644.0,
#   '8': 389952.0,
#   '9': 25612995.408,
#   '10': 92691.17400000001,
#   '11': 92691.174,
#   '12': 395457.86,
#   '13': 515168.416,
#   '14': 248240.732,
#   '15': 369141.576,
#   '16': 140453.41,
#   '17': 1742249.81,
#   '18': 409499.23,
#   '19': 487272.758,
#   '20': 485658.943,
#   '21': 1000164.2,
#   '22': 226546.32,
#   '23': 2033322.291,
#   '24': 890129.74,
#   '25': 1498.9479999999999,
#   '26': 1107454.67,
#   '27': 307069.48,
#   '28': 2345626.848,
#   '29': 5678797.936,
#   '30': 361030.0,
#   '31': 715528.029,
#   '32': 577328.029,
#   '33': 387848.988},
#  'value_after_haircut': {'0': 116285.68530000001,
#   '1': 113914.4292,
#   '2': 1023676.9199999999,
#   '3': 423424.1628,
#   '4': 4199.535,
#   '5': 315672.84,
#   '6': 2611189.53555,
