# %%
import requests
import json

# %%
token = "9b0d6ca2db3de2046e5093db6908b2655159e5b5"

# %%
headers={"Authorization":f"Token {token}" }
path = '/home/beedata/Documents/uni/DataIngestionWebApp/pythonProject/WebApp/sample_data/Tech task data - Sheet1.csv'
files = {"upload_file": open(path,"r")}

r = requests.post('http://localhost:8000/data-ingestion/invoice-upload/', headers=headers,files=files)
r
# Out:
# <Response [200]>

# %%
r.content
# Out:
# b'"POST API and you have uploaded a  file"'

# %%
headers={"Authorization":f"Token {token}" }
payload = {'revenue_source':'Happy Playcrows'}
r = requests.get("http://localhost:8000/data-ingestion/invoice-advance/", headers=headers, data=payload)
r
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/Documents/venvs/djangosamplewebapp/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# ...

# %%
r.json()
# Out:
# [{'invoice_number': '3531'},
#  {'invoice_number': '3710'},
#  {'invoice_number': '3533'},
#  {'invoice_number': '3534'},
#  {'invoice_number': '3536'},
#  {'invoice_number': '3579'},
#  {'invoice_number': '3600'},
#  {'invoice_number': '3080'},
#  {'invoice_number': '3583'},
#  {'invoice_number': '3539'},
#  {'invoice_number': '3593'},
#  {'invoice_number': '3541'},
#  {'invoice_number': '3618'},
#  {'invoice_number': '3610'},
#  {'invoice_number': '3609'},
#  {'invoice_number': '3608'},
#  {'invoice_number': '3535'},
#  {'invoice_number': '3081'},
#  {'invoice_number': '2148'},
#  {'invoice_number': '3079'},
#  {'invoice_number': '3078'},
#  {'invoice_number': '3076'},
#  {'invoice_number': '3075'},
#  {'invoice_number': '2193'},
#  {'invoice_number': '3711'},
#  {'invoice_number': '3712'},
#  {'invoice_number': '3713'},
#  {'invoice_number': '3715'},
#  {'invoice_number': '2107'},
#  {'invoice_number': '5134'},
#  {'invoice_number': '3383'},
#  {'invoice_number': '6798'},
# ...
